# %% [markdown]
# <a href="https://colab.research.google.com/github/TeeshynaJ/-anime_forecasting/blob/main/API_Kaggle_join.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
batch1=pd.read_csv('batch1.csv')
batch4=pd.read_csv('batch4.csv')
batch5=pd.read_csv('batch5.csv')
batch6=pd.read_csv('batch6.csv')
batch7=pd.read_csv('batch7.csv')
batch8=pd.read_csv('batch8.csv')

# %%
concatenated_df = pd.concat([batch1, batch4, batch5, batch6, batch7, batch8], axis=0)

# %%
concatenated_df.head()
# Out:
#      id   idMal                   title format  episodes  duration     status  \
# 0   103   103.0  Red Riding Hood Chacha     TV      74.0      24.0   FINISHED
# 1   235   235.0             Case Closed     TV       NaN      25.0  RELEASING
# 2  1638  1638.0       Peter Pan & Wendy     TV      41.0      23.0   FINISHED
# 3  1826  1826.0           Deltora Quest     TV      65.0      25.0   FINISHED
# 4  1860  1860.0             Tokyo Majin     TV      14.0      24.0   FINISHED
#
#    startDay  startMonth  startYear  ...  favourites  \
# 0       7.0         1.0     1994.0  ...          67
# 1       8.0         1.0     1996.0  ...        4661
# 2      15.0         1.0     1989.0  ...           9
# 3       6.0         1.0     2007.0  ...          83
# 4      19.0         1.0     2007.0  ...         109
#
#                                               genres  \
# 0  ['Adventure', 'Comedy', 'Fantasy', 'Mahou Shou...
# 1  ['Adventure', 'Comedy', 'Mystery', 'Psychologi...
# ...

# %%
concatenated_df.to_csv("concatenated_batches.csv", index=False)

# %% [markdown]
# JOIN BATCHES WITH KAGGLE **bold text**

# %%
kaggle_df = pd.read_csv('/content/Kaggle_filtered_to_tv.csv')
